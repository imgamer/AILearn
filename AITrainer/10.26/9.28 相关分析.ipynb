# %%
import pandas as pd
data = pd.read_csv('test/身高体重数据集.csv')
data
# Out:
#      Gender  Height  Weigh
# 0         0     156     38
# 1         1     155     50
# 2         0     181     68
# 3         1     177     77
# 4         1     171     74
# ..      ...     ...    ...
# 995       0     165     49
# 996       0     167     62
# 997       1     167     57
# 998       1     173     66
# 999       1     182     74
#
# [1000 rows x 3 columns]

# %%
data.corr()
# Out:
#           Gender    Height     Weigh
# Gender  1.000000  0.538076  0.638066
# Height  0.538076  1.000000  0.873978
# Weigh   0.638066  0.873978  1.000000

# %%
import matplotlib.pyplot as plt
plt.rcParams['lines.markersize'] = 3
plt.scatter(data['Height'], data['Weigh'], color = 'r')
plt.show()

# %%
from scipy.stats import pearsonr
c,p = pearsonr(data['Height'], data['Weigh'])
print(p)
print(c)
# Out:
# 4.93467037e-315
# 0.8739777445997816
